# %%
import pandas as pd

# %%
data = pd.read_csv("fulldata2.csv")
cities = pd.read_csv("GeoLiteCities.csv")
locations = pd.read_csv("GeoLitLocations.csv")
cities2 = pd.read_csv("worldcities.csv")
# Out:
# C:\Users\alana\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cities2['Birthplace'] = cities2['country'] + " " + cities2['city']
cities2 = cities2.drop(columns = ['city_ascii', 'iso2', 'iso3',
       'admin_name', 'capital', 'population', 'id'])

# %%
data = data.drop(columns = ['birthMonth', 'birthDay',
       'birthState', 'deathMonth', 'deathDay',
       'deathState',
       'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
       'retroID', 'bbrefID', 'Position', 'HoF'])

# %%
namer={"USA": "United States","Curaçao" : "Curacao", "D.R.": "Dominican Republic", 'CAN': "Canada", "P.R.": "Puerto Rico", "V.I.": "U.S. Virgin Islands"}

# %%
data = data.replace({"birthCountry": namer})

# %%
cities2.columns
# Out:
# Index(['city', 'lat', 'lng', 'country', 'Birthplace'], dtype='object')

# %%
data = data.dropna(subset=['birthCountry'])
data = data.dropna(subset=['birthCity'])

# %%
cities = cities.drop(columns=['network', 'represented_country_geoname_id', 'is_anonymous_proxy',
       'is_satellite_provider', 'postal_code', 'accuracy_radius'])

# %%
locations = locations.drop(columns=['locale_code', 'continent_name', 'subdivision_1_iso_code',
       'subdivision_1_name', 'subdivision_2_iso_code', 'subdivision_2_name',
       'time_zone', 'is_in_european_union', 'metro_code'])

# %%
cities[cities.geoname_id == 3553478]
# Out:
#        geoname_id  registered_country_geoname_id  latitude  longitude
# 73484   3553478.0                      3562981.0   23.1319   -82.3642
# 73485   3553478.0                      3562981.0   23.1319   -82.3642
# 73486   3553478.0                      3562981.0   23.1319   -82.3642
# 73487   3553478.0                      3562981.0   23.1319   -82.3642

# %%
locator = locations.merge(cities, on = "geoname_id", how = "left")

# %%
locator = locator.drop_duplicates(subset=['geoname_id'], keep='first')

# %%
locator[locator.city_name == 'St Petersburg'].sort_values(by=['city_name'])
# Out:
#        geoname_id continent_code country_iso_code country_name      city_name  \
# 19969      498817             EU               RU       Russia  St Petersburg
#
#        registered_country_geoname_id  latitude  longitude
# 19969                      2017370.0   59.7513    30.4766

# %%
data['Birthplace'] = data['birthCountry'] + " " + data['birthCity']

# %%
locator['Birthplace'] = locator['country_name'] + " " + locator['city_name']

# %%
final2 = data.merge(cities2, on='Birthplace', how='left')

# %%
final = data.merge(locator, on='Birthplace', how='left')

# %%
final.iloc[46767, final.columns.get_loc('latitude')] = 46.0994
final.iloc[46767, final.columns.get_loc('longitude')] = 37.02617

# %%
final2
# Out:
#        Unnamed: 0   playerID  birthYear        birthCountry         birthCity  \
# 0               0  aardsda01     1981.0       United States            Denver
# 1               1  aaronha01     1934.0       United States            Mobile
# 2               2  aaronto01     1939.0       United States            Mobile
# 3               3   aasedo01     1954.0       United States            Orange
# 4               3   aasedo01     1954.0       United States            Orange
# 5               3   aasedo01     1954.0       United States            Orange
# 6               4   abadan01     1972.0       United States        Palm Beach
# 7               5   abadfe01     1985.0  Dominican Republic         La Romana
# 8               6  abadijo01     1850.0       United States      Philadelphia
# 9               6  abadijo01     1850.0       United States      Philadelphia
# 10              7  abbated01     1877.0       United States           Latrobe
# 11              8  abbeybe01     1869.0       United States             Essex
# 12              9  abbeych01     1866.0       United States        Falls City
# 13             10  abbotda01     1862.0       United States           Portage
# 14             10  abbotda01     1862.0       United States           Portage
# 15             10  abbotda01     1862.0       United States           Portage
# 16             10  abbotda01     1862.0       United States           Portage
# 17             11  abbotfr01     1874.0       United States        Versailles
# 18             12  abbotgl01     1951.0       United States       Little Rock
# 19             13  abbotje01     1972.0       United States           Atlanta
# 20             13  abbotje01     1972.0       United States           Atlanta
# 21             14  abbotji01     1967.0       United States             Flint
# 22             15  abbotku01     1969.0       United States        Zanesville
# 23             16  abbotky01     1968.0       United States       Newburyport
# 24             17  abbotod01     1886.0       United States         New Eagle
# 25             18  abbotpa01     1967.0       United States          Van Nuys
# 26             19   aberal01     1927.0       United States         Cleveland
# 27             19   aberal01     1927.0       United States         Cleveland
# 28             19   aberal01     1927.0       United States         Cleveland
# 29             19   aberal01     1927.0       United States         Cleveland
# ...           ...        ...        ...                 ...               ...
# 33867       19596  zinteal01     1968.0       United States           El Paso
# 33868       19597  zipfebu01     1938.0       United States        Belleville
# 33869       19598   ziskri01     1949.0       United States          Brooklyn
# 33870       19598   ziskri01     1949.0       United States          Brooklyn
# 33871       19599   zitoba01     1978.0       United States         Las Vegas
# 33872       19599   zitoba01     1978.0       United States         Las Vegas
# 33873       19600  zitzmbi01     1895.0       United States  Long Island City
# 33874       19601  zmiched01     1884.0       United States         Cleveland
# 33875       19601  zmiched01     1884.0       United States         Cleveland
# 33876       19601  zmiched01     1884.0       United States         Cleveland
# 33877       19601  zmiched01     1884.0       United States         Cleveland
# 33878       19601  zmiched01     1884.0       United States         Cleveland
# 33879       19602  zobribe01     1981.0       United States            Eureka
# 33880       19602  zobribe01     1981.0       United States            Eureka
# 33881       19602  zobribe01     1981.0       United States            Eureka
# 33882       19603  zoccope01     1977.0       United States             Bronx
# 33883       19604  zoldasa01     1918.0       United States          Brooklyn
# 33884       19604  zoldasa01     1918.0       United States          Brooklyn
# 33885       19605  zoskyed01     1968.0       United States          Whittier
# 33886       19606  zuberbi01     1913.0       United States      Middle Amana
# 33887       19607  zuberjo01     1969.0       United States            Encino
# 33888       19608  zuletju01     1975.0              Panama            Panama
# 33889       19609  zumayjo01     1984.0       United States       Chula Vista
# 33890       19610  zuninmi01     1991.0       United States        Cape Coral
# 33891       19611  zupcibo01     1966.0       United States        Pittsburgh
# 33892       19612   zupofr01     1939.0       United States     San Francisco
# 33893       19613  zuvelpa01     1958.0       United States         San Mateo
# 33894       19614  zuverge01     1924.0       United States           Holland
# 33895       19615  zwilldu01     1888.0       United States         St. Louis
# 33896       19616   zychto01     1990.0       United States             Monee
#
#        deathYear deathCountry         deathCity nameFirst     nameLast  \
# 0            NaN          NaN               NaN     David      Aardsma
# 1            NaN          NaN               NaN      Hank        Aaron
# 2         1984.0          USA           Atlanta    Tommie        Aaron
# 3            NaN          NaN               NaN       Don         Aase
# 4            NaN          NaN               NaN       Don         Aase
# 5            NaN          NaN               NaN       Don         Aase
# 6            NaN          NaN               NaN      Andy         Abad
# 7            NaN          NaN               NaN  Fernando         Abad
# 8         1905.0          USA         Pemberton      John       Abadie
# 9         1905.0          USA         Pemberton      John       Abadie
# 10        1957.0          USA   Fort Lauderdale        Ed  Abbaticchio
# 11        1962.0          USA        Colchester      Bert        Abbey
# 12        1926.0          USA     San Francisco   Charlie        Abbey
# 13        1930.0          USA       Ottawa Lake       Dan       Abbott
# 14        1930.0          USA       Ottawa Lake       Dan       Abbott
# 15        1930.0          USA       Ottawa Lake       Dan       Abbott
# 16        1930.0          USA       Ottawa Lake       Dan       Abbott
# 17        1935.0          USA       Los Angeles      Fred       Abbott
# 18           NaN          NaN               NaN     Glenn       Abbott
# 19           NaN          NaN               NaN      Jeff       Abbott
# 20           NaN          NaN               NaN      Jeff       Abbott
# 21           NaN          NaN               NaN       Jim       Abbott
# 22           NaN          NaN               NaN      Kurt       Abbott
# 23           NaN          NaN               NaN      Kyle       Abbott
# 24        1933.0          USA        Washington       Ody       Abbott
# 25           NaN          NaN               NaN      Paul       Abbott
# 26        1993.0          USA  Garfield Heights        Al         Aber
# 27        1993.0          USA  Garfield Heights        Al         Aber
# 28        1993.0          USA  Garfield Heights        Al         Aber
# 29        1993.0          USA  Garfield Heights        Al         Aber
# ...          ...          ...               ...       ...          ...
# 33867        NaN          NaN               NaN      Alan       Zinter
# 33868        NaN          NaN               NaN       Bud       Zipfel
# 33869        NaN          NaN               NaN    Richie         Zisk
# 33870        NaN          NaN               NaN    Richie         Zisk
# 33871        NaN          NaN               NaN     Barry         Zito
# 33872        NaN          NaN               NaN     Barry         Zito
# 33873     1985.0          USA           Passaic     Billy     Zitzmann
# 33874     1950.0          USA         Cleveland        Ed        Zmich
# 33875     1950.0          USA         Cleveland        Ed        Zmich
# 33876     1950.0          USA         Cleveland        Ed        Zmich
# 33877     1950.0          USA         Cleveland        Ed        Zmich
# 33878     1950.0          USA         Cleveland        Ed        Zmich
# 33879        NaN          NaN               NaN       Ben      Zobrist
# 33880        NaN          NaN               NaN       Ben      Zobrist
# 33881        NaN          NaN               NaN       Ben      Zobrist
# 33882        NaN          NaN               NaN     Peter   Zoccolillo
# 33883     1966.0          USA     New Hyde Park       Sam       Zoldak
# 33884     1966.0          USA     New Hyde Park       Sam       Zoldak
# 33885        NaN          NaN               NaN     Eddie        Zosky
# 33886     1982.0          USA      Cedar Rapids      Bill        Zuber
# 33887        NaN          NaN               NaN       Jon        Zuber
# 33888        NaN          NaN               NaN     Julio       Zuleta
# 33889        NaN          NaN               NaN      Joel       Zumaya
# 33890        NaN          NaN               NaN      Mike       Zunino
# 33891        NaN          NaN               NaN       Bob       Zupcic
# 33892     2005.0          USA        Burlingame     Frank         Zupo
# 33893        NaN          NaN               NaN      Paul      Zuvella
# 33894     2014.0          USA             Tempe    George     Zuverink
# 33895     1978.0          USA      La Crescenta     Dutch     Zwilling
# 33896        NaN          NaN               NaN      Tony         Zych
#
#                            Birthplace           city      lat       lng  \
# 0                United States Denver         Denver  39.7621 -104.8759
# 1                United States Mobile         Mobile  30.6783  -88.1162
# 2                United States Mobile         Mobile  30.6783  -88.1162
# 3                United States Orange         Orange  38.2486  -78.1127
# 4                United States Orange         Orange  30.1209  -93.7616
# 5                United States Orange         Orange  33.8038 -117.8219
# 6            United States Palm Beach     Palm Beach  26.6852  -80.0403
# 7        Dominican Republic La Romana      La Romana  18.4170  -68.9666
# 8          United States Philadelphia   Philadelphia  40.0076  -75.1340
# 9          United States Philadelphia   Philadelphia  32.7761  -89.1221
# 10              United States Latrobe        Latrobe  40.3125  -79.3825
# 11                United States Essex            NaN      NaN       NaN
# 12           United States Falls City            NaN      NaN       NaN
# 13              United States Portage        Portage  43.5490  -89.4659
# 14              United States Portage        Portage  40.3869  -78.6747
# 15              United States Portage        Portage  41.5866  -87.1792
# 16              United States Portage        Portage  42.2000  -85.5906
# 17           United States Versailles     Versailles  38.0488  -84.7260
# 18          United States Little Rock    Little Rock  34.7255  -92.3581
# 19              United States Atlanta        Atlanta  33.1136  -94.1672
# 20              United States Atlanta        Atlanta  33.7626  -84.4228
# 21                United States Flint          Flint  43.0236  -83.6922
# 22           United States Zanesville     Zanesville  39.9567  -82.0133
# 23          United States Newburyport    Newburyport  42.8124  -70.8879
# 24            United States New Eagle            NaN      NaN       NaN
# 25             United States Van Nuys            NaN      NaN       NaN
# 26            United States Cleveland      Cleveland  30.3368  -95.0924
# 27            United States Cleveland      Cleveland  35.1817  -84.8707
# 28            United States Cleveland      Cleveland  34.5971  -83.7622
# 29            United States Cleveland      Cleveland  41.4767  -81.6805
# ...                               ...            ...      ...       ...
# 33867           United States El Paso        El Paso  31.8479 -106.4309
# 33868        United States Belleville     Belleville  38.5165  -89.9899
# 33869          United States Brooklyn       Brooklyn  40.6501  -73.9496
# 33870          United States Brooklyn       Brooklyn  41.4349  -81.7498
# 33871         United States Las Vegas      Las Vegas  35.6011 -105.2206
# 33872         United States Las Vegas      Las Vegas  36.2291 -115.2607
# 33873  United States Long Island City            NaN      NaN       NaN
# 33874         United States Cleveland      Cleveland  30.3368  -95.0924
# 33875         United States Cleveland      Cleveland  35.1817  -84.8707
# 33876         United States Cleveland      Cleveland  34.5971  -83.7622
# 33877         United States Cleveland      Cleveland  41.4767  -81.6805
# 33878         United States Cleveland      Cleveland  33.7440  -90.7285
# 33879            United States Eureka         Eureka  40.7941 -124.1568
# 33880            United States Eureka         Eureka  40.7147  -89.2776
# 33881            United States Eureka         Eureka  38.5013  -90.6491
# 33882             United States Bronx          Bronx  40.8501  -73.8662
# 33883          United States Brooklyn       Brooklyn  40.6501  -73.9496
# 33884          United States Brooklyn       Brooklyn  41.4349  -81.7498
# 33885          United States Whittier       Whittier  33.9678 -118.0188
# 33886      United States Middle Amana            NaN      NaN       NaN
# 33887            United States Encino            NaN      NaN       NaN
# 33888                   Panama Panama            NaN      NaN       NaN
# 33889       United States Chula Vista    Chula Vista  32.6281 -117.0145
# 33890        United States Cape Coral     Cape Coral  26.6444  -81.9956
# 33891        United States Pittsburgh     Pittsburgh  40.4396  -79.9763
# 33892     United States San Francisco  San Francisco  37.7562 -122.4430
# 33893         United States San Mateo      San Mateo  37.5522 -122.3122
# 33894           United States Holland        Holland  42.7677  -86.0984
# 33895         United States St. Louis            NaN      NaN       NaN
# 33896             United States Monee          Monee  41.4172  -87.7504
#
#                   country
# 0           United States
# 1           United States
# 2           United States
# 3           United States
# 4           United States
# 5           United States
# 6           United States
# 7      Dominican Republic
# 8           United States
# 9           United States
# 10          United States
# 11                    NaN
# 12                    NaN
# 13          United States
# 14          United States
# 15          United States
# 16          United States
# 17          United States
# 18          United States
# 19          United States
# 20          United States
# 21          United States
# 22          United States
# 23          United States
# 24                    NaN
# 25                    NaN
# 26          United States
# 27          United States
# 28          United States
# 29          United States
# ...                   ...
# 33867       United States
# 33868       United States
# 33869       United States
# 33870       United States
# 33871       United States
# 33872       United States
# 33873                 NaN
# 33874       United States
# 33875       United States
# 33876       United States
# 33877       United States
# 33878       United States
# 33879       United States
# 33880       United States
# 33881       United States
# 33882       United States
# 33883       United States
# 33884       United States
# 33885       United States
# 33886                 NaN
# 33887                 NaN
# 33888                 NaN
# 33889       United States
# 33890       United States
# 33891       United States
# 33892       United States
# 33893       United States
# 33894       United States
# 33895                 NaN
# 33896       United States
#
# [33897 rows x 15 columns]

# %%
final = final.dropna(subset=['latitude'])

# %%
final= final.drop_duplicates(subset=['playerID'], keep='first')

# %%
final.to_csv("final.csv")

# %%
# Cuba, Russia, Czech Republic, Hong Kong, Denmark, Switzerland, Audtria, China, Belize, Indonesia, Finland, Lithuania, Slovakia, American Samoa, POrtugal, Honduras, Latvia
