# %%
import sqlite3
import sqlalchemy
import pandas
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, desc
sqlite_file = 'data.sqlite'

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("data.sqlite")
df = pd.read_sql_query("select * from deploy1;", conn)
df
# Out:
#        level_0  index birthYear nameFirst     nameLast        BLat  \
# 0            0      0      1981     David      Aardsma  39.7392358
# 1            1      1      1934      Hank        Aaron  30.6953657
# 2            2      2      1939    Tommie        Aaron  30.6953657
# 3            3      3      1954       Don         Aase  33.7879139
# 4            4      4      1972      Andy         Abad  26.7056206
# 5            5      5      1985  Fernando         Abad  18.4338645
# 6            6      6      1850      John       Abadie  39.9525839
# 7            7      7      1877        Ed  Abbaticchio  40.3211808
# 8            8      8      1869      Bert        Abbey  44.4905054
# 9            9      9      1866   Charlie        Abbey  40.0608352
# 10          10     10      1862       Dan       Abbott  41.3267189
# 11          11     11      1874      Fred       Abbott  40.2225481
# 12          12     12      1951     Glenn       Abbott  34.7464809
# ...

# %%
df[df.nameLast == 'Happ']
# Out:
#      birthYear nameFirst nameLast        BLat         BLng   birthCountry  \
# 7276      1994       Ian     Happ   40.340923   -76.411346  United States
# 7277      1982     J. A.     Happ  41.3275349  -89.1289728  United States
#
#      deathYear birthCity                                               Flag
# 7276             Lebanon  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 7277                Peru  https://upload.wikimedia.org/wikipedia/en/a/a4...

# %%
df.iloc[7276, df.columns.get_loc('BLat')] = 40.3553 
df.iloc[7276, df.columns.get_loc('BLng')] = -80.0495
df.iloc[7276, df.columns.get_loc('birthCity')] = "Mt. Lebanon"

# %%
mycur = conn.cursor() 
# mycur.execute("DROP TABLE 'Deploy1';")
mycur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
available_table=(mycur.fetchall())

# %%
available_table
# Out:
# [('deploy1',)]

# %%
df.to_sql('deploy1', conn)

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'birthYear', 'nameFirst', 'nameLast', 'BLat',
#        'BLng', 'birthCountry', 'deathYear', 'birthCity', 'Flag'],
#       dtype='object')

# %%
df = df.drop(columns = ['level_0', 'index'])

# %%
df.columns
# Out:
# Index(['birthYear', 'nameFirst', 'nameLast', 'BLat', 'BLng', 'birthCountry',
#        'deathYear', 'birthCity', 'Flag'],
#       dtype='object')
