# %%
import sqlite3
import sqlalchemy
import pandas
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, desc
sqlite_file = 'data.sqlite'

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("baseball.sqlite")
df = pd.read_sql_query("select * from final limit 5;", conn)
df
# Out:
#        playerID birthYear   birthCountry   birthCity deathYear deathCountry  \
# 0  0  aardsda01    1981.0  United States      Denver
# 1  1  aaronha01    1934.0  United States      Mobile
# 2  2  aaronto01    1939.0  United States      Mobile    1984.0          USA
# 3  3   aasedo01    1954.0  United States      Orange
# 4  4   abadan01    1972.0  United States  Palm Beach
#
#   deathCity nameFirst nameLast  \
# 0               David  Aardsma
# 1                Hank    Aaron
# 2   Atlanta    Tommie    Aaron
# 3                 Don     Aase
# 4                Andy     Abad
#
#                          ...                         continent_code  \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   country_iso_code   country_name   city_name registered_country_geoname_id  \
# 0               US  United States      Denver                     6252001.0
# 1               US  United States      Mobile                     6252001.0
# 2               US  United States      Mobile                     6252001.0
# 3               US  United States      Orange                     6252001.0
# 4               US  United States  Palm Beach                     6252001.0
#
#   latitude longitude      lat        lng  \
# 0  35.4837  -80.9898  39.7621  -104.8759
# 1  30.5928  -88.1946  30.6783   -88.1162
# 2  30.5928  -88.1946  30.6783   -88.1162
# 3  30.0709  -93.8659  38.2486   -78.1127
# 4  26.7206  -80.0388  26.6852   -80.0403
#
#                                                flags
# 0  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 1  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 2  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 3  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 4  https://upload.wikimedia.org/wikipedia/en/a/a4...
#
# [5 rows x 22 columns]

# %%
mycur = conn.cursor() 
mycur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
available_table=(mycur.fetchall())

# %%
available_table
# Out:
# [('Deploy1',)]
