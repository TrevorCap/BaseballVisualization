# %%
import pandas as pd

# %%
data = pd.read_csv("fulldata.csv")
cities = pd.read_csv("GeoLiteCities.csv")
locations = pd.read_csv("GeoLitLocations.csv")
# Out:
# C:\Users\alana\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
locations.head()
# Out:
#    geoname_id locale_code continent_code continent_name country_iso_code  \
# 0        5822          en             EU         Europe               CY
# 1       49518          en             AF         Africa               RW
# 2       49747          en             AF         Africa               SO
# 3       51537          en             AF         Africa               SO
# 4       53654          en             AF         Africa               SO
#
#   country_name subdivision_1_iso_code subdivision_1_name  \
# 0       Cyprus                      2           Limassol
# 1       Rwanda                    NaN                NaN
# 2      Somalia                     BK             Bakool
# 3      Somalia                    NaN                NaN
# 4      Somalia                     BN           Banaadir
#
#   subdivision_2_iso_code subdivision_2_name  city_name  metro_code  \
# 0                    NaN                NaN    Zanakia         NaN
# ...

# %%
data[data.birthCountry == 'Russia'].sort_values(by=['birthCity'])
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 6303   gettmja01     1875.0        10.0      25.0       Russia        NaN
# 15708  schauru01     1891.0         3.0      19.0       Russia        NaN
# 3785   cristbi01     1875.0         9.0      12.0       Russia        NaN
# 5272   ewingre01     1899.0        11.0      30.0       Russia        NaN
# 6523   goldsiz01     1908.0         6.0       6.0       Russia        NaN
# 3346    colevi01     1968.0         1.0      23.0       Russia        NaN
# 10325  livinja01     1875.0         3.0      22.0       Russia        NaN
# 136    ainsmed01     1890.0         2.0       4.0       Russia        NaN
#
#             birthCity  deathYear  deathMonth  deathDay ... weight height bats  \
# 6303            Frank     1956.0        10.0       4.0 ...  185.0   71.0    B
# 15708         Kamenka     1957.0         4.0      15.0 ...  192.0   74.0    R
# ...

# %%
data.iloc[3346, data.columns.get_loc('birthCity')] = "St Petersburg"

# %%
locations[locations.country_name == 'Cuba'].sort_values(by=['city_name'])
# Out:
#         geoname_id locale_code continent_code continent_name country_iso_code  \
# 80570      3567033          en            NaN  North America               CU
# 80569      3566356          en            NaN  North America               CU
# 82028      3746183          en            NaN  North America               CU
# 80568      3563946          en            NaN  North America               CU
# 80566      3557689          en            NaN  North America               CU
# 80563      3553478          en            NaN  North America               CU
# 80565      3556969          en            NaN  North America               CU
# 80564      3553479          en            NaN  North America               CU
# 82029      3746184          en            NaN  North America               CU
# 80562      3549470          en            NaN  North America               CU
# 80561      3547640          en            NaN  North America               CU
# ...

# %%
cities[cities.geoname_id == 3567033]
# Out:
#               network  geoname_id  registered_country_geoname_id  \
# 54462   4.16.182.0/30   3567033.0                      6252001.0
# 54463   4.16.182.4/32   3567033.0                      6252001.0
# 54464   4.16.182.6/31   3567033.0                      6252001.0
# 54465   4.16.182.8/29   3567033.0                      6252001.0
# 54466  4.16.182.16/28   3567033.0                      6252001.0
# 54467  4.16.182.32/27   3567033.0                      6252001.0
# 54468  4.16.182.64/26   3567033.0                      6252001.0
#
#        represented_country_geoname_id  is_anonymous_proxy  \
# 54462                       6252001.0                   0
# 54463                       6252001.0                   0
# 54464                       6252001.0                   0
# 54465                       6252001.0                   0
# 54466                       6252001.0                   0
# 54467                       6252001.0                   0
# ...

# %%
 data = data.to_csv("fulldata2.csv")
